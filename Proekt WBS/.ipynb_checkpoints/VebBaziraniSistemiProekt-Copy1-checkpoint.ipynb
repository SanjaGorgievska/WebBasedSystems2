# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
import math

# %%
import re

# %%
data1 = pd.read_csv('countries1.csv')

# %%
data1
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# ...           ...       ...   ...             ...         ...           ...
# 1699     Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700     Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701     Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702     Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703     Zimbabwe    Africa  2007          43.487    12311143    469.709298
#
# [1704 rows x 6 columns]

# %%
us = data1[data1.country == 'United States']

# %%
us
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 1608  United States  Americas  1952          68.440   157553000   13990.48208
# 1609  United States  Americas  1957          69.490   171984000   14847.12712
# 1610  United States  Americas  1962          70.210   186538000   16173.14586
# 1611  United States  Americas  1967          70.760   198712000   19530.36557
# 1612  United States  Americas  1972          71.340   209896000   21806.03594
# 1613  United States  Americas  1977          73.380   220239000   24072.63213
# 1614  United States  Americas  1982          74.650   232187835   25009.55914
# 1615  United States  Americas  1987          75.020   242803533   29884.35041
# 1616  United States  Americas  1992          76.090   256894189   32003.93224
# 1617  United States  Americas  1997          76.810   272911760   35767.43303
# 1618  United States  Americas  2002          77.310   287675526   39097.09955
# ...

# %%
china = data1[data1.country == 'China']

# %%
china
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 288   China      Asia  1952        44.00000   556263527    400.448611
# 289   China      Asia  1957        50.54896   637408000    575.987001
# 290   China      Asia  1962        44.50136   665770000    487.674018
# 291   China      Asia  1967        58.38112   754550000    612.705693
# 292   China      Asia  1972        63.11888   862030000    676.900092
# 293   China      Asia  1977        63.96736   943455000    741.237470
# 294   China      Asia  1982        65.52500  1000281000    962.421380
# 295   China      Asia  1987        67.27400  1084035000   1378.904018
# 296   China      Asia  1992        68.69000  1164970000   1655.784158
# 297   China      Asia  1997        70.42600  1230075000   2289.234136
# 298   China      Asia  2002        72.02800  1280400000   3119.280896
# 299   China      Asia  2007        72.96100  1318683096   4959.114854

# %%
norway = data1[data1.country == 'Norway']

# %%
norway
# Out:
#      country continent  year  lifeExpectancy  population  gdpPerCapita
# 1140  Norway    Europe  1952          72.670     3327728   10095.42172
# 1141  Norway    Europe  1957          73.440     3491938   11653.97304
# 1142  Norway    Europe  1962          73.470     3638919   13450.40151
# 1143  Norway    Europe  1967          74.080     3786019   16361.87647
# 1144  Norway    Europe  1972          74.340     3933004   18965.05551
# 1145  Norway    Europe  1977          75.370     4043205   23311.34939
# 1146  Norway    Europe  1982          75.970     4114787   26298.63531
# 1147  Norway    Europe  1987          75.890     4186147   31540.97480
# 1148  Norway    Europe  1992          77.320     4286357   33965.66115
# 1149  Norway    Europe  1997          78.320     4405672   41283.16433
# 1150  Norway    Europe  2002          79.050     4535591   44683.97525
# 1151  Norway    Europe  2007          80.196     4627926   49357.19017

# %%
plt.plot(us.year, us.population)
plt.title('Population in United States')
plt.legend(['United States'])
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()

# %%
data_country = set(data1.country)

# %%
data_country
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Bahrain',
#  'Bangladesh',
#  'Belgium',
#  'Benin',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Haiti',
#  'Honduras',
#  'Hong Kong, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
# ...

# %%
meanUS = us.population.mean()

# %%
print(meanUS)
# Out:
# 228211232.5

# %%
medianUS = us.population.median()

# %%
print(medianUS)
# Out:
# 226213417.5

# %%
plt.plot(meanUS,medianUS, 'red')

# %%
plt.subplot(2,1,1)
plt.hist(us.population,20,range=(0,1500000000), edgecolor = 'black')
plt.title('Population in United States and China')
plt.ylabel('United States')
plt.subplot(2,1,2)
plt.hist(china.population,20,range=(0,1500000000), edgecolor = 'black')
plt.ylabel('China')
plt.show()

# %%
plt.plot(us.year, us.population / 10 ** 6)
plt.plot(china.year,china.population / 10 ** 6)
plt.legend(['United States', 'China'])
plt.title('Population in Us through years')
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()

# %%
us_growth = us.population / us.population.iloc[0] * 100
china_growth = china.population / china.population.iloc[0] * 100
plt.plot(us.year, us_growth)
plt.plot(china.year,china_growth)
plt.legend(['United States', 'China'])
plt.title('Population in Us through years')
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()

# %%
data_2002 = data1[data1.year == 2002]
america2002 = data_2002[data_2002.continent == 'Americas']
europe2002 = data_2002[data_2002.continent == 'Europe']

# %%
data_2002
# Out:
#                  country continent  year  lifeExpectancy  population  \
# 10           Afghanistan      Asia  2002          42.129    25268405
# 22               Albania    Europe  2002          75.651     3508512
# 34               Algeria    Africa  2002          70.994    31287142
# 46                Angola    Africa  2002          41.003    10866106
# 58             Argentina  Americas  2002          74.340    38331121
# ...                  ...       ...   ...             ...         ...
# 1654             Vietnam      Asia  2002          73.017    80908147
# 1666  West Bank and Gaza      Asia  2002          72.370     3389578
# 1678         Yemen, Rep.      Asia  2002          60.308    18701257
# 1690              Zambia    Africa  2002          39.193    10595811
# 1702            Zimbabwe    Africa  2002          39.989    11926563
#
#       gdpPerCapita
# 10      726.734055
# 22     4604.211737
# 34     5288.040382
# 46     2773.287312
# 58     8797.640716
# ...

# %%
america2002.country
# Out:
# 58                Argentina
# 142                 Bolivia
# 178                  Brazil
# 250                  Canada
# 286                   Chile
# 310                Colombia
# 358              Costa Rica
# 394                    Cuba
# 442      Dominican Republic
# 454                 Ecuador
# 478             El Salvador
# 610               Guatemala
# 646                   Haiti
# 658                Honduras
# 790                 Jamaica
# 994                  Mexico
# 1114              Nicaragua
# 1186                 Panama
# 1198               Paraguay
# 1210                   Peru
# 1258            Puerto Rico
# 1558    Trinidad and Tobago
# 1618          United States
# 1630                Uruguay
# 1642              Venezuela
# Name: country, dtype: object

# %%
europe2002.country
# Out:
# 22                     Albania
# 82                     Austria
# 118                    Belgium
# 154     Bosnia and Herzegovina
# 190                   Bulgaria
# 382                    Croatia
# 406             Czech Republic
# 418                    Denmark
# 526                    Finland
# 538                     France
# 574                    Germany
# 598                     Greece
# 682                    Hungary
# 694                    Iceland
# 754                    Ireland
# 778                      Italy
# 1018                Montenegro
# 1090               Netherlands
# 1150                    Norway
# 1234                    Poland
# 1246                  Portugal
# 1282                   Romania
# 1342                    Serbia
# 1378           Slovak Republic
# 1390                  Slovenia
# 1426                     Spain
# 1474                    Sweden
# 1486               Switzerland
# 1582                    Turkey
# 1606            United Kingdom
# ...

# %%
plt.subplot(2,1,1)
plt.hist(america2002.lifeExpectancy,20, range=(50,90), edgecolor = 'black')
plt.title('Life Expectancy in 2002 in America and Europe')
plt.ylabel('America')
plt.subplot(2,1,2)
plt.hist(europe2002.lifeExpectancy,20, range=(50,90), edgecolor = 'black')
plt.ylabel('Europe')
plt.show()

# %%
america2002[america2002.lifeExpectancy < 65]
# Out:
#      country continent  year  lifeExpectancy  population  gdpPerCapita
# 142  Bolivia  Americas  2002          63.883     8445134   3413.262690
# 646    Haiti  Americas  2002          58.137     7607651   1270.364932

# %%
data_2002
# Out:
#                  country continent  year  lifeExpectancy  population  \
# 10           Afghanistan      Asia  2002          42.129    25268405
# 22               Albania    Europe  2002          75.651     3508512
# 34               Algeria    Africa  2002          70.994    31287142
# 46                Angola    Africa  2002          41.003    10866106
# 58             Argentina  Americas  2002          74.340    38331121
# ...                  ...       ...   ...             ...         ...
# 1654             Vietnam      Asia  2002          73.017    80908147
# 1666  West Bank and Gaza      Asia  2002          72.370     3389578
# 1678         Yemen, Rep.      Asia  2002          60.308    18701257
# 1690              Zambia    Africa  2002          39.193    10595811
# 1702            Zimbabwe    Africa  2002          39.989    11926563
#
#       gdpPerCapita
# 10      726.734055
# 22     4604.211737
# 34     5288.040382
# 46     2773.287312
# 58     8797.640716
# ...

# %%
plt.scatter(np.log10(data_2002.gdpPerCapita), data_2002.lifeExpectancy, 6)
plt.title('GDP and LifeExpectancy Correlation')
plt.xlabel('GDP')
plt.ylabel('Life Expectancy')
plt.show()

# %%
data_2002.gdpPerCapita.corr(data_2002.lifeExpectancy)
# Out:
# 0.6818577877946372

# %%
years_sorted = sorted(set(data1.year))

# %%
for given_year in years_sorted:
    data_year = data1[data1.year  == given_year]
    plt.scatter(np.log10(data_year.gdpPerCapita), data_year.lifeExpectancy, 6)
    plt.xlabel('GDP')
    plt.ylabel('Life Expectancy')
    plt.xlim(2,5)
    plt.title(given_year)
    plt.show()

# %%
top10 = data_2002.sort_values('population', ascending=False).head(10)

# %%
top10
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 298           China      Asia  2002          72.028  1280400000   3119.280896
# 706           India      Asia  2002          62.879  1034172547   1746.769454
# 1618  United States  Americas  2002          77.310   287675526  39097.099550
# 718       Indonesia      Asia  2002          68.588   211060000   2873.912870
# 178          Brazil  Americas  2002          71.006   179914212   8131.212843
# 1174       Pakistan      Asia  2002          63.610   153403524   2092.712441
# 106      Bangladesh      Asia  2002          62.013   135656790   1136.390430
# 802           Japan      Asia  2002          82.000   127065841  28604.591900
# 1138        Nigeria    Africa  2002          46.608   119901274   1615.286395
# 994          Mexico  Americas  2002          74.902   102479927  10742.440530

# %%
x = range(10)
plt.bar(x,top10.population / 10**9)
plt.title('Population by top 10 countries in the world in bilions ')
plt.xticks(x,top10.country, rotation='vertical')
plt.show()

# %%
x = np.arange(10)

# We need to create subplots in order to overlay two bar plots
# with proper axes on the left hand side and the right hand side.
fig, ax1 = plt.subplots()

width = 0.3 # This is the width of each bar in the bar plot.
plt.xticks(x, top10.country, rotation='vertical')
population = ax1.bar(x, top10.population / 10**6, width)
plt.ylabel('Population')

# ax1.twinx() gives us the same x-axis with the y-axis on the right.
ax2 = ax1.twinx()
gdp = ax2.bar(x + width, top10.gdpPerCapita * top10.population / 10**9,
              width, color='orange')
plt.ylabel('GDP')
plt.legend([population, gdp],
           ['Population in Millions', 'GDP in Billions'])
figure = plt.gcf() # get current figure
plt.show()

# %%
data = pd.read_csv('populationbysex.csv')
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data
# Out:
#        LocID     location  VarID      Variant    year  MidPeriod       male  \
# 0          4  Afghanistan    2.0       Medium  1950.0     1950.5   4099.243
# 1          4  Afghanistan    2.0       Medium  1951.0     1951.5   4134.756
# 2          4  Afghanistan    2.0       Medium  1952.0     1952.5   4174.450
# 3          4  Afghanistan    2.0       Medium  1953.0     1953.5   4218.336
# 4          4  Afghanistan    2.0       Medium  1954.0     1954.5   4266.484
# ...      ...          ...    ...          ...     ...        ...        ...
# 280927   716     Zimbabwe  207.0  Lower 95 PI  2080.0     2080.5  10576.533
# 280928   716     Zimbabwe  207.0  Lower 95 PI  2085.0     2085.5  10293.349
# 280929   716     Zimbabwe  207.0  Lower 95 PI  2090.0     2090.5   9920.336
# 280930   716     Zimbabwe  207.0  Lower 95 PI  2095.0     2095.5   9503.711
# 280931   716     Zimbabwe  207.0  Lower 95 PI  2100.0     2100.5   9090.075
#
#            female      total  density
# ...

# %%
data.head()
# Out:
#   LocID     location  VarID Variant    year  MidPeriod      male    female  \
# 0     4  Afghanistan    2.0  Medium  1950.0     1950.5  4099.243  3652.874
# 1     4  Afghanistan    2.0  Medium  1951.0     1951.5  4134.756  3705.395
# 2     4  Afghanistan    2.0  Medium  1952.0     1952.5  4174.450  3761.546
# 3     4  Afghanistan    2.0  Medium  1953.0     1953.5  4218.336  3821.348
# 4     4  Afghanistan    2.0  Medium  1954.0     1954.5  4266.484  3884.832
#
#       total  density
# 0  7752.117   11.874
# 1  7840.151   12.009
# 2  7935.996   12.156
# 3  8039.684   12.315
# 4  8151.316   12.486

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280932 entries, 0 to 280931
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   LocID      280932 non-null  object
#  1   location   275175 non-null  object
#  2   VarID      275175 non-null  float64
#  3   Variant    275175 non-null  object
#  4   year       275175 non-null  float64
#  5   MidPeriod  275175 non-null  float64
#  6   male       246003 non-null  float64
#  7   female     246003 non-null  float64
#  8   total      275175 non-null  float64
#  9   density    275175 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 21.4+ MB

# %%
data.shape
# Out:
# (280932, 10)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.isnull().sum()
# Out:
# LocID            0
# location      5757
# VarID         5757
# Variant       5757
# year          5757
# MidPeriod     5757
# male         34929
# female       34929
# total         5757
# density       5757
# dtype: int64

# %%
data.dropna(axis=1)
# Out:
#        LocID
# 0          4
# 1          4
# 2          4
# 3          4
# 4          4
# ...      ...
# 280927   716
# 280928   716
# 280929   716
# 280930   716
# 280931   716
#
# [280932 rows x 1 columns]

# %%
data.dropna(how='any')
# Out:
#        LocID     location  VarID      Variant    year  MidPeriod       male  \
# 0          4  Afghanistan    2.0       Medium  1950.0     1950.5   4099.243
# 1          4  Afghanistan    2.0       Medium  1951.0     1951.5   4134.756
# 2          4  Afghanistan    2.0       Medium  1952.0     1952.5   4174.450
# 3          4  Afghanistan    2.0       Medium  1953.0     1953.5   4218.336
# 4          4  Afghanistan    2.0       Medium  1954.0     1954.5   4266.484
# ...      ...          ...    ...          ...     ...        ...        ...
# 280927   716     Zimbabwe  207.0  Lower 95 PI  2080.0     2080.5  10576.533
# 280928   716     Zimbabwe  207.0  Lower 95 PI  2085.0     2085.5  10293.349
# 280929   716     Zimbabwe  207.0  Lower 95 PI  2090.0     2090.5   9920.336
# 280930   716     Zimbabwe  207.0  Lower 95 PI  2095.0     2095.5   9503.711
# 280931   716     Zimbabwe  207.0  Lower 95 PI  2100.0     2100.5   9090.075
#
#            female      total  density
# ...

# %%
data.fillna(3000)
# Out:
#        LocID     location  VarID      Variant    year  MidPeriod       male  \
# 0          4  Afghanistan    2.0       Medium  1950.0     1950.5   4099.243
# 1          4  Afghanistan    2.0       Medium  1951.0     1951.5   4134.756
# 2          4  Afghanistan    2.0       Medium  1952.0     1952.5   4174.450
# 3          4  Afghanistan    2.0       Medium  1953.0     1953.5   4218.336
# 4          4  Afghanistan    2.0       Medium  1954.0     1954.5   4266.484
# ...      ...          ...    ...          ...     ...        ...        ...
# 280927   716     Zimbabwe  207.0  Lower 95 PI  2080.0     2080.5  10576.533
# 280928   716     Zimbabwe  207.0  Lower 95 PI  2085.0     2085.5  10293.349
# 280929   716     Zimbabwe  207.0  Lower 95 PI  2090.0     2090.5   9920.336
# 280930   716     Zimbabwe  207.0  Lower 95 PI  2095.0     2095.5   9503.711
# 280931   716     Zimbabwe  207.0  Lower 95 PI  2100.0     2100.5   9090.075
#
#            female      total  density
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.values
# Out:
# array([['4', 'Afghanistan', 2.0, ..., 3652.8740000000003,
#         7752.116999999999, 11.874],
#        ['4', 'Afghanistan', 2.0, ..., 3705.395, 7840.151, 12.009],
#        ['4', 'Afghanistan', 2.0, ..., 3761.546, 7935.996,
#         12.155999999999999],
#        ...,
#        [716, 'Zimbabwe', 207.0, ..., 10767.708999999999,
#         20689.956000000002, 53.483000000000004],
#        [716, 'Zimbabwe', 207.0, ..., 10412.184000000001, 19892.08,
#         51.42100000000001],
#        [716, 'Zimbabwe', 207.0, ..., 9996.105, 19061.177, 49.273]],
#       dtype=object)

# %%
data.drop(['LocID','VarID'],axis=1)
# Out:
#            location      Variant    year  MidPeriod       male     female  \
# 0       Afghanistan       Medium  1950.0     1950.5   4099.243   3652.874
# 1       Afghanistan       Medium  1951.0     1951.5   4134.756   3705.395
# 2       Afghanistan       Medium  1952.0     1952.5   4174.450   3761.546
# 3       Afghanistan       Medium  1953.0     1953.5   4218.336   3821.348
# 4       Afghanistan       Medium  1954.0     1954.5   4266.484   3884.832
# ...             ...          ...     ...        ...        ...        ...
# 280927     Zimbabwe  Lower 95 PI  2080.0     2080.5  10576.533  11255.983
# 280928     Zimbabwe  Lower 95 PI  2085.0     2085.5  10293.349  11050.875
# 280929     Zimbabwe  Lower 95 PI  2090.0     2090.5   9920.336  10767.709
# 280930     Zimbabwe  Lower 95 PI  2095.0     2095.5   9503.711  10412.184
# 280931     Zimbabwe  Lower 95 PI  2100.0     2100.5   9090.075   9996.105
#
#             total  density
# 0        7752.117   11.874
# ...

# %%
data2010 = data[(data.year > 2009) & (data.year < 2020)]

# %%
data2010.drop(['LocID', 'VarID', 'MidPeriod'], axis=1)
# Out:
#            location Variant    year       male     female      total  density
# 60      Afghanistan  Medium  2010.0  14935.756  14249.755  29185.511   44.704
# 61      Afghanistan  Medium  2011.0  15415.361  14702.050  30117.411   46.131
# 62      Afghanistan  Medium  2012.0  15964.874  15196.504  31161.378   47.731
# 63      Afghanistan  Medium  2013.0  16554.278  15715.314  32269.592   49.428
# 64      Afghanistan  Medium  2014.0  17138.803  16232.001  33370.804   51.115
# ...             ...     ...     ...        ...        ...        ...      ...
# 280113     Zimbabwe  Medium  2015.0   6568.778   7245.864  13814.642   35.711
# 280114     Zimbabwe  Medium  2016.0   6674.206   7356.132  14030.338   36.268
# 280115     Zimbabwe  Medium  2017.0   6777.054   7459.545  14236.599   36.801
# 280116     Zimbabwe  Medium  2018.0   6879.119   7559.693  14438.812   37.324
# 280117     Zimbabwe  Medium  2019.0   6983.353   7662.120  14645.473   37.858
#
# [4680 rows x 7 columns]

# %%
macedonia = data[data.location == 'North Macedonia']

# %%
macedonia = macedonia[macedonia.year < 2020]
macedonia
# Out:
#        LocID         location  VarID Variant    year  MidPeriod      male  \
# 181833   807  North Macedonia    2.0  Medium  1950.0     1950.5   629.564
# 181834   807  North Macedonia    2.0  Medium  1951.0     1951.5   648.952
# 181835   807  North Macedonia    2.0  Medium  1952.0     1952.5   665.344
# 181836   807  North Macedonia    2.0  Medium  1953.0     1953.5   679.486
# 181837   807  North Macedonia    2.0  Medium  1954.0     1954.5   691.964
# ...      ...              ...    ...     ...     ...        ...       ...
# 181898   807  North Macedonia    2.0  Medium  2015.0     2015.5  1040.400
# 181899   807  North Macedonia    2.0  Medium  2016.0     2016.5  1041.178
# 181900   807  North Macedonia    2.0  Medium  2017.0     2017.5  1041.785
# 181901   807  North Macedonia    2.0  Medium  2018.0     2018.5  1042.177
# 181902   807  North Macedonia    2.0  Medium  2019.0     2019.5  1042.305
#
#           female     total  density
# 181833   624.880  1254.444   49.740
# ...

# %%
plt.plot(macedonia.year, macedonia.male)
plt.plot(macedonia.year,macedonia.female)
plt.legend(['Male', 'Femae'])
plt.title('Population in Macedonia through years')
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()

# %%
macedonia.shape
# Out:
# (70, 10)

# %%
macedonia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70 entries, 181833 to 181902
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LocID      70 non-null     object
#  1   location   70 non-null     object
#  2   VarID      70 non-null     float64
#  3   Variant    70 non-null     object
#  4   year       70 non-null     float64
#  5   MidPeriod  70 non-null     float64
#  6   male       70 non-null     float64
#  7   female     70 non-null     float64
#  8   total      70 non-null     float64
#  9   density    70 non-null     float64
# dtypes: float64(7), object(3)
# memory usage: 6.0+ KB

# %%
macedonia.columns
# Out:
# Index(['LocID', 'location', 'VarID', 'Variant', 'year', 'MidPeriod', 'male',
#        'female', 'total', 'density'],
#       dtype='object')

# %%
macedonia.isnull().sum()
# Out:
# LocID        0
# location     0
# VarID        0
# Variant      0
# year         0
# MidPeriod    0
# male         0
# female       0
# total        0
# density      0
# dtype: int64

# %%
type(macedonia)
# Out:
# pandas.core.frame.DataFrame

# %%
macedonia2020 = macedonia.loc[macedonia['year'] == 2019, ['location','year','male', 'female', 'total', 'density']]

# %%
macedonia2020
# Out:
#                location    year      male    female     total  density
# 181902  North Macedonia  2019.0  1042.305  1041.153  2083.458   82.611

# %%
macedonia2020.duplicated().sum()
# Out:
# 0

# %%
macedonia.fillna(0)
# Out:
#        LocID         location  VarID Variant    year  MidPeriod      male  \
# 181833   807  North Macedonia    2.0  Medium  1950.0     1950.5   629.564
# 181834   807  North Macedonia    2.0  Medium  1951.0     1951.5   648.952
# 181835   807  North Macedonia    2.0  Medium  1952.0     1952.5   665.344
# 181836   807  North Macedonia    2.0  Medium  1953.0     1953.5   679.486
# 181837   807  North Macedonia    2.0  Medium  1954.0     1954.5   691.964
# ...      ...              ...    ...     ...     ...        ...       ...
# 181898   807  North Macedonia    2.0  Medium  2015.0     2015.5  1040.400
# 181899   807  North Macedonia    2.0  Medium  2016.0     2016.5  1041.178
# 181900   807  North Macedonia    2.0  Medium  2017.0     2017.5  1041.785
# 181901   807  North Macedonia    2.0  Medium  2018.0     2018.5  1042.177
# 181902   807  North Macedonia    2.0  Medium  2019.0     2019.5  1042.305
#
#           female     total  density
# 181833   624.880  1254.444   49.740
# ...

# %%
data2010
# Out:
#        LocID     location  VarID Variant    year  MidPeriod       male  \
# 60         4  Afghanistan    2.0  Medium  2010.0     2010.5  14935.756
# 61         4  Afghanistan    2.0  Medium  2011.0     2011.5  15415.361
# 62         4  Afghanistan    2.0  Medium  2012.0     2012.5  15964.874
# 63         4  Afghanistan    2.0  Medium  2013.0     2013.5  16554.278
# 64         4  Afghanistan    2.0  Medium  2014.0     2014.5  17138.803
# ...      ...          ...    ...     ...     ...        ...        ...
# 280113   716     Zimbabwe    2.0  Medium  2015.0     2015.5   6568.778
# 280114   716     Zimbabwe    2.0  Medium  2016.0     2016.5   6674.206
# 280115   716     Zimbabwe    2.0  Medium  2017.0     2017.5   6777.054
# 280116   716     Zimbabwe    2.0  Medium  2018.0     2018.5   6879.119
# 280117   716     Zimbabwe    2.0  Medium  2019.0     2019.5   6983.353
#
#            female      total  density
# 60      14249.755  29185.511   44.704
# ...

# %%
decimals = data2010['year'].apply(lambda x: str(x).split('.')[1])

# %%
decimals
# Out:
# 60        0
# 61        0
# 62        0
# 63        0
# 64        0
#          ..
# 280113    0
# 280114    0
# 280115    0
# 280116    0
# 280117    0
# Name: year, Length: 4680, dtype: object
